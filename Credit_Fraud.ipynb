# %%
# !pip install imblearn

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.ensemble import RandomForestClassifier
from imblearn.over_sampling import SMOTE

# %%
train = pd.read_csv('train.csv')
original = pd.read_csv('creditcard.csv')

# %%
train.head()
# Out:
#    id  Time        V1        V2        V3        V4        V5        V6  \
# 0   0   0.0  2.074329 -0.129425 -1.137418  0.412846 -0.192638 -1.210144
# 1   1   0.0  1.998827 -1.250891 -0.520969 -0.894539 -1.122528 -0.270866
# 2   2   0.0  0.091535  1.004517 -0.223445 -0.435249  0.667548 -0.988351
# 3   3   0.0  1.979649 -0.184949 -1.064206  0.120125 -0.215238 -0.648829
# 4   4   0.0  1.025898 -0.171827  1.203717  1.243900 -0.636572  1.099074
#
#          V7        V8  ...       V21       V22       V23       V24       V25  \
# 0  0.110697 -0.263477  ... -0.334701 -0.887840  0.336701 -0.110835 -0.291459
# 1 -1.029289  0.050198  ...  0.054848 -0.038367  0.133518 -0.461928 -0.465491
# 2  0.948146 -0.084789  ... -0.326725 -0.803736  0.154495  0.951233 -0.506919
# 3 -0.087826 -0.035367  ... -0.095514 -0.079792  0.167701 -0.042939  0.000799
# 4 -0.938651  0.569239  ...  0.099157  0.608908  0.027901 -0.262813  0.257834
#
#         V26       V27       V28  Amount  Class
# 0  0.207733 -0.076576 -0.059577    1.98      0
# 1 -0.464655 -0.009413 -0.038238   84.00      0
# 2  0.085046  0.224458  0.087356    2.69      0
# 3 -0.096148 -0.057780 -0.073839    1.00      0
# 4 -0.252829  0.108338  0.021051    1.00      0
#
# [5 rows x 32 columns]

# %%
original.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
merged = pd.concat([train.drop(['id'], axis=1), original])
merged['TimeofDay'] = pd.cut(
    merged.Time % (3600 * 24),
    bins=[0, 6, 12, 18, 24],
    labels=["early_morning", "morning", "afternoon", "night"]
)

# %%
merged.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0  2.074329 -0.129425 -1.137418  0.412846 -0.192638 -1.210144  0.110697
# 1   0.0  1.998827 -1.250891 -0.520969 -0.894539 -1.122528 -0.270866 -1.029289
# 2   0.0  0.091535  1.004517 -0.223445 -0.435249  0.667548 -0.988351  0.948146
# 3   0.0  1.979649 -0.184949 -1.064206  0.120125 -0.215238 -0.648829 -0.087826
# 4   0.0  1.025898 -0.171827  1.203717  1.243900 -0.636572  1.099074 -0.938651
#
#          V8        V9  ...       V22       V23       V24       V25       V26  \
# 0 -0.263477  0.742144  ... -0.887840  0.336701 -0.110835 -0.291459  0.207733
# 1  0.050198 -0.109948  ... -0.038367  0.133518 -0.461928 -0.465491 -0.464655
# 2 -0.084789 -0.042027  ... -0.803736  0.154495  0.951233 -0.506919  0.085046
# 3 -0.035367  0.885838  ... -0.079792  0.167701 -0.042939  0.000799 -0.096148
# 4  0.569239  0.692665  ...  0.608908  0.027901 -0.262813  0.257834 -0.252829
#
#         V27       V28  Amount  Class  TimeofDay
# 0 -0.076576 -0.059577    1.98      0        NaN
# 1 -0.009413 -0.038238   84.00      0        NaN
# 2  0.224458  0.087356    2.69      0        NaN
# 3 -0.057780 -0.073839    1.00      0        NaN
# 4  0.108338  0.021051    1.00      0        NaN
#
# [5 rows x 32 columns]

# %%
X = merged.drop(['Class'], axis=1)
y = merged['Class']

# %%
sm = SMOTE(random_state=42)
X_res, y_res = sm.fit_resample(X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, train_size=0.8, stratify=y_res)

# %%
scaler = StandardScaler()
clf = RandomForestClassifier(class_weight='balanced', verbose=2)

pipe = Pipeline([
    ('scaler', scaler),
    ('classifier', clf)
])

param_grid = {
    'classifier__n_estimators': [50, 100],
    'classifier__max_depth': [3, 5, 10]
}

grid = GridSearchCV(pipe, param_grid, cv=5, scoring='roc_auc')
grid.fit(X_train, y_train)

# %%
print("Best Parameters:", grid.best_params_)
print("Best Score:", grid.best_score_)

# %%
roc_auc_score(y_test, grid.best_estimator_.predict(X_test))
